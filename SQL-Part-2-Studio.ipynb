-- %% [markdown]
-- # Lesson 11: SQL Part 2 Studio
--
-- > This studio asks you to create queries using the functions from this lesson. As you work through the studio, you may need to create more than one query to return the desired answer.  For others, you may need to combine functions together in order to answer the original query.  The questions have been organized in a way to help you puzzle out the answers.
-- >
-- > Happy querying!
--
-- **The Dataset:**
--
-- > We will be working with the **BooksDB dataset** from Lesson 10.  You should already have access to it.

-- %% [markdown]
-- ## The Questions:

-- %% [markdown]
-- 1.  Create a query that returns the longest title in the dataset.  We can do this in two steps.
--
-- > A. Create a query that returns the length of the longest title.
-- >
-- > B. Create a query that uses the length you found in step A to find the longest title.

-- %%
-- Code here:
--A
SELECT MAX(LEN(title))
FROM BooksDB.dbo.books

--B
Select title, book_id
FROM BooksDB.dbo.books
WHERE LEN(title) = (SELECT MAX(LEN(title))
FROM BooksDB.dbo.books)
-- Out:
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.090
-- <table><tr><th>(No column name)</th></tr><tr><td>186</td></tr></table>
-- <table><tr><th>title</th><th>book_id</th></tr><tr><td>Soccernomics: Why England Loses, Why Germany and Brazil Win, and Why the U.S., Japan, Australia, Turkey--and Even Iraq--Are Destined to Become the Kings of the World's Most Popular Sport</td><td>6617185</td></tr></table>

-- %% [markdown]
-- 2.  Use what you learned in question 1 to find the shortest author name.
--
-- > A. Create a query that returns the length of the shortest author.
-- >
-- > B. Create a query that returns the shortest author's name.

-- %%
-- Code here:
--A
SELECT MIN(LEN(authors))
FROM BooksDB.dbo.books

--B
Select authors, book_id
FROM BooksDB.dbo.books
WHERE LEN(authors) = (SELECT MIN(LEN(authors))
FROM BooksDB.dbo.books)
-- Out:
-- (1 row affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.093
-- <table><tr><th>(No column name)</th></tr><tr><td>3</td></tr></table>
-- <table><tr><th>authors</th><th>book_id</th></tr><tr><td>Avi</td><td>310146</td></tr><tr><td>Avi</td><td>353342</td></tr></table>

-- %% [markdown]
-- 3\. How many titles contain the word "The"?
--
--
--
-- > A. Is there a difference between the number of titles that use "The" or "the"?

-- %%
-- Code here:
SELECT Count(title)
FROM BooksDB.dbo.books
WHERE title LIKE '%The%';

SELECT Count(title)
FROM BooksDB.dbo.books
WHERE title LIKE '%the%'
-- Out:
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.110
-- <table><tr><th>(No column name)</th></tr><tr><td>4702</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>4702</td></tr></table>

-- %% [markdown]
-- 4.  How many authors' names _start_ with 'Z'?

-- %%
-- Code here:
SELECT authors 
FROM BooksDB.dbo.books
WHERE authors LIKE 'Z%'
-- Out:
-- (11 rows affected)
-- Total execution time: 00:00:00.110
-- <table><tr><th>authors</th></tr><tr><td>Zora Neale Hurston</td></tr><tr><td>Zadie Smith</td></tr><tr><td>Zadie Smith</td></tr><tr><td>Zoe Sugg, Siobhan Curham</td></tr><tr><td>Zadie Smith</td></tr><tr><td>Zilpha Keatley Snyder</td></tr><tr><td>Zane</td></tr><tr><td>Zoë Heller</td></tr><tr><td>Zadie Smith</td></tr><tr><td>Zig Ziglar, Al Mayton</td></tr><tr><td>Zadie Smith</td></tr></table>

-- %% [markdown]
-- 5\. How many books have been identified as printed in a language other than English?  There are four language codes for English: 'en', 'eng', 'en-US', and 'en-UK'.  Use LEFT to answer the question.  (Do not use the wildcard)
--
-- You might want to use one of these [comparison operators](https://docs.microsoft.com/en-us/sql/t-sql/language-elements/comparison-operators-transact-sql?view=sql-server-ver15).

-- %%
-- Code here:
SELECT COUNT(*) AS None_English
FROM BooksDB.dbo.books
WHERE LEFT(language_code, 6) <> 'en' 
AND LEFT(language_code, 6) <> 'eng'
AND LEFT(language_code, 6) <> 'en-US'
AND LEFT(language_code, 6) <> 'en-UK'

Select top 20 * from BooksDB.dbo.books
-- Out:
-- (1 row affected)
-- (20 rows affected)
-- Total execution time: 00:00:00.067
-- <table><tr><th>None_English</th></tr><tr><td>501</td></tr></table>
-- <table><tr><th>id</th><th>book_id</th><th>best_book_id</th><th>work_id</th><th>books_count</th><th>isbn</th><th>isbn13</th><th>authors</th><th>original_publication_year</th><th>original_title</th><th>title</th><th>language_code</th><th>average_rating</th><th>ratings_count</th><th>work_ratings_count</th><th>work_text_reviews_count</th><th>ratings_1</th><th>ratings_2</th><th>ratings_3</th><th>ratings_4</th><th>ratings_5</th><th>image_url</th><th>small_image_url</th></tr><tr><td>1</td><td>2767052</td><td>2767052</td><td>2792775</td><td>272</td><td>439023483</td><td>9780439023480</td><td>Suzanne Collins</td><td>2008</td><td>The Hunger Games</td><td>The Hunger Games (The Hunger Games, #1)</td><td>eng</td><td>4.34</td><td>4780653</td><td>4942365</td><td>155254</td><td>66715</td><td>127936</td><td>560092</td><td>1481305</td><td>2706317</td><td>https://images.gr-assets.com/books/1447303603m/2767052.jpg</td><td>https://images.gr-assets.com/books/1447303603s/2767052.jpg</td></tr><tr><td>2</td><td>3</td><td>3</td><td>4640799</td><td>491</td><td>439554934</td><td>9780439554930</td><td>J.K. Rowling, Mary GrandPré</td><td>1997</td><td>Harry Potter and the Philosopher's Stone</td><td>Harry Potter and the Sorcerer's Stone (Harry Potter, #1)</td><td>eng</td><td>4.44</td><td>4602479</td><td>4800065</td><td>75867</td><td>75504</td><td>101676</td><td>455024</td><td>1156318</td><td>3011543</td><td>https://images.gr-assets.com/books/1474154022m/3.jpg</td><td>https://images.gr-assets.com/books/1474154022s/3.jpg</td></tr><tr><td>3</td><td>41865</td><td>41865</td><td>3212258</td><td>226</td><td>316015849</td><td>9780316015840</td><td>Stephenie Meyer</td><td>2005</td><td>Twilight</td><td>Twilight (Twilight, #1)</td><td>en-US</td><td>3.57</td><td>3866839</td><td>3916824</td><td>95009</td><td>456191</td><td>436802</td><td>793319</td><td>875073</td><td>1355439</td><td>https://images.gr-assets.com/books/1361039443m/41865.jpg</td><td>https://images.gr-assets.com/books/1361039443s/41865.jpg</td></tr><tr><td>4</td><td>2657</td><td>2657</td><td>3275794</td><td>487</td><td>61120081</td><td>9780061120080</td><td>Harper Lee</td><td>1960</td><td>To Kill a Mockingbird</td><td>To Kill a Mockingbird</td><td>eng</td><td>4.25</td><td>3198671</td><td>3340896</td><td>72586</td><td>60427</td><td>117415</td><td>446835</td><td>1001952</td><td>1714267</td><td>https://images.gr-assets.com/books/1361975680m/2657.jpg</td><td>https://images.gr-assets.com/books/1361975680s/2657.jpg</td></tr><tr><td>5</td><td>4671</td><td>4671</td><td>245494</td><td>1356</td><td>743273567</td><td>9780743273560</td><td>F. Scott Fitzgerald</td><td>1925</td><td>The Great Gatsby</td><td>The Great Gatsby</td><td>eng</td><td>3.89</td><td>2683664</td><td>2773745</td><td>51992</td><td>86236</td><td>197621</td><td>606158</td><td>936012</td><td>947718</td><td>https://images.gr-assets.com/books/1490528560m/4671.jpg</td><td>https://images.gr-assets.com/books/1490528560s/4671.jpg</td></tr><tr><td>6</td><td>11870085</td><td>11870085</td><td>16827462</td><td>226</td><td>525478817</td><td>9780525478810</td><td>John Green</td><td>2012</td><td>The Fault in Our Stars</td><td>The Fault in Our Stars</td><td>eng</td><td>4.26</td><td>2346404</td><td>2478609</td><td>140739</td><td>47994</td><td>92723</td><td>327550</td><td>698471</td><td>1311871</td><td>https://images.gr-assets.com/books/1360206420m/11870085.jpg</td><td>https://images.gr-assets.com/books/1360206420s/11870085.jpg</td></tr><tr><td>7</td><td>5907</td><td>5907</td><td>1540236</td><td>969</td><td>618260307</td><td>9780618260300</td><td>J.R.R. Tolkien</td><td>1937</td><td>The Hobbit or There and Back Again</td><td>The Hobbit</td><td>en-US</td><td>4.25</td><td>2071616</td><td>2196809</td><td>37653</td><td>46023</td><td>76784</td><td>288649</td><td>665635</td><td>1119718</td><td>https://images.gr-assets.com/books/1372847500m/5907.jpg</td><td>https://images.gr-assets.com/books/1372847500s/5907.jpg</td></tr><tr><td>8</td><td>5107</td><td>5107</td><td>3036731</td>< ...

-- %% [markdown]
-- 6\. Retry question 5 using SUBSTRING.

-- %%
-- Code here:
SELECT COUNT(*) AS None_English
FROM BooksDB.dbo.books
WHERE SUBSTRING(language_code, 1, 6) not IN ('en', 'eng', 'en-US', 'en-UK')
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.052
-- <table><tr><th>None_English</th></tr><tr><td>501</td></tr></table>

-- %% [markdown]
-- 7.  Create a column that returns the title, authors, and language codes.  Concatenate these elements so that they return in the following way: title by authors in language\_code language.
--
-- > A.  Check each selected column to see where any values are NULL.  Did any of the columns contain NULL values?  If so, which one?

-- %%
-- Code here:
SELECT CONCAT(title, ' by ', authors, language_code) AS book_info
FROM BooksDB.dbo.books
WHERE title IS NULL OR authors IS NULL OR language_code IS NULL
-- Out:
-- (1084 rows affected)
-- Total execution time: 00:00:00.230
-- <table><tr><th>book_info</th></tr><tr><td>Life of Pi by Yann Martel</td></tr><tr><td>The Five People You Meet in Heaven by Mitch Albom</td></tr><tr><td>A Christmas Carol by Charles Dickens</td></tr><tr><td>Carrie by Stephen King</td></tr><tr><td>The Hunt for Red October (Jack Ryan Universe, #4) by Tom Clancy</td></tr><tr><td>Where the Red Fern Grows by Wilson Rawls</td></tr><tr><td>Fried Green Tomatoes at the Whistle Stop Caf
ith by Jodi Picoult</td></tr><tr><td>Ham on Rye by Charles Bukowski</td></tr><tr><td>Emotional Intelligence 2.0 by Travis Bradberry, Jean Greaves, Patrick Lencioni</td></tr><tr><td>Make Way for Ducklings by Robert McCloskey</td></tr><tr><td>On the Banks of Plum Creek  (Little House, #4) by Laura Ingalls Wilder, Garth Williams</td></tr><tr><td>PostSecret: Extraordinary Confessions from Ordinary Lives (PostSecret) by Frank Warren</td></tr><tr><td>The Borrowers (The Borrowers, #1) by Mary Norton, Beth Krush, Joe Krush</td></tr ...

-- %% [markdown]
-- 8.  Update the query in question 7 using COALESCE to change the language code values from NULL to 'unknown'.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
SELECT CONCAT(title, ' by ', authors, COALESCE(language_code, 'unknown')) AS book_info
FROM BooksDB.dbo.books
WHERE language_code IS NULL
-- Out:
-- (1084 rows affected)
-- Total execution time: 00:00:00.164
-- <table><tr><th>book_info</th></tr><tr><td>Life of Pi by Yann Martelunknown</td></tr><tr><td>The Five People You Meet in Heaven by Mitch Albomunknown</td></tr><tr><td>A Christmas Carol by Charles Dickensunknown</td></tr><tr><td>Carrie by Stephen Kingunknown</td></tr><tr><td>The Hunt for Red October (Jack Ryan Universe, #4) by Tom Clancyunknown</td></tr><tr><td>Where the Red Fern Grows by Wilson Rawlsunknown</td></tr><tr><td>Fried Green Tomatoes at the Whistle Stop Cafe by Fannie Flaggunknown</td></tr><tr><td>The Three Musketeers by Alexandre Dumasunknown</td></tr><tr><td>In Her Shoes by Jennifer Weinerunknown</td></tr><tr><td>The Andromeda Strain by Michael Crichtonunknown</td></tr><tr><td>Needful Things by Stephen Kingunknown</td></tr><tr><td>Are You There, Vodka? It's Me, Chelsea by Chelsea Handlerunknown</td></tr><tr><td>Prey by Michael Crichtonunknown</td></tr><tr><td>Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1) by Robert C. O'Brienunknown</td></tr><tr><td>The Little House Collection (Little House, #1-9) by Laura Ingalls Wilder, Garth Williamsunknown</td></tr><tr><td>The Girls' Guide to Hunting and Fishing by Melissa Bankunknown</td></tr><tr><td>Sh*t My Dad Says by Justin Halpernunknown</td></tr><tr><td>The Four Agreements: A Practical Guide to Personal Freedom by Miguel Ruizunknown</td></tr><tr><td>One Fish, Two Fish, Red Fish, Blue Fish by Dr. Seussunknown</td></tr><tr><td>Watchers by Dean Koontzunknown</td></tr><tr><td>Fifty Shades Trilogy (Fifty Shades, #1-3) by E.L. Jamesunknown</td></tr><tr><td>The Joy of Cooking by Irma S. Rombauer, Marion Rombauer Becker, Ethan Beckerunknown</td></tr><tr><td>The Complete Anne of Green Gables Boxed Set (Anne of Green Gables, #1-8) by L.M. Montgomeryunknown</td></tr><tr><td>The Partner by John Grishamunknown</td></tr><tr><td>Presumed Innocent by Scott Turowunknown</td></tr><tr><td>Dr. Seuss's Green Eggs and Ham: For Soprano, Boy Soprano, and Orchestra by Robert Kapilow, Dr. Seussunknown</td></tr><tr><td>Inferno (The Divine Comedy #1) by Dante Alighieri, Anthony M. Esolenunknown</td></tr><tr><td>The Girl Who Loved Tom Gordon by Stephen Kingunknown</td></tr><tr><td>The Twilight Saga (Twilight, #1-4) by Stephenie Meyer, Ilyana Kadushin, Matt Waltersunknown</td></tr><tr><td>The Secret Keeper by Kate Mortonunknown</td></tr><tr><td>Better Homes and Gardens New Cook Book   by Better Homes and Gardensunknown</td></tr><tr><td>Reached (Matched, #3) by Ally Condieunknown</td></tr><tr><td>The Testament by John Grishamunknown</td></tr><tr><td>90 Minutes in Heaven: A True Story of Death and Life by Don Piper, Cecil Murpheyunknown</td></tr><tr><td>Sam's Letters to Jennifer by James Pattersonunknown</td></tr><tr><td>Little Earthquakes by Jennifer Weinerunknown</td></tr><tr><td>Lullaby by Chuck Palahniukunknown</td></tr><tr><td>The English Patient by Michael Ondaatjeunknown</td></tr><tr><td>Warm Bodies (Warm Bodies, #1) by Isaac Marionunknown</td></tr><tr><td>Cold Sassy Tree by Olive Ann Burnsunknown</td></tr><tr><td>Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe, #1) by Benjamin Alire Sáenzunknown</td></tr><tr><td>Summer Sisters by Judy Blumeunknown</td></tr><tr><td>A Scandal in Bohemia (The Adventures of Sherlock Holmes, #1) by Ronald Holt, Arthur Conan Doyleunknown</td></tr><tr><td>The Brethren by John Grishamunknown</td></tr><tr><td>The Case for Christ by Lee Strobelunknown</td></tr><tr><td>The Complete Sherlock Holmes, Vol 2 by Arthur Conan Doyle, Kyle Freemanunknown</td></tr><tr><td>The Pilgrim's Progress by John Bunyanunknown</td></tr><tr><td>Janet Evanovich Three and Four Two-Book Set (Stephanie Plum, #3-4) by Janet Evanovichunknown</td></tr><tr><td>Magician's Gambit (The Belgariad, #3) by David Eddingsunknown</td></tr><tr><td>Keeping Faith by Jodi Picoultunknown</td></tr><tr><td>Ham on Rye by Charles Bukowskiunknown</td></tr><tr><td>Emotional Intelligence 2.0 by Travis Bradberry, Jean Greaves, Patrick Lencioniunknown</ ...

-- %% [markdown]
-- 9\. Revisit question 7 using ISNULL instead of COALESCE.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
SELECT CONCAT(title, ' by ', authors, isnull(language_code, 'unknown')) AS book_info
FROM BooksDB.dbo.books
WHERE language_code IS NULL
-- Out:
-- (1084 rows affected)
-- Total execution time: 00:00:00.164
-- <table><tr><th>book_info</th></tr><tr><td>Life of Pi by Yann Martelunknown</td></tr><tr><td>The Five People You Meet in Heaven by Mitch Albomunknown</td></tr><tr><td>A Christmas Carol by Charles Dickensunknown</td></tr><tr><td>Carrie by Stephen Kingunknown</td></tr><tr><td>The Hunt for Red October (Jack Ryan Universe, #4) by Tom Clancyunknown</td></tr><tr><td>Where the Red Fern Grows by Wilson Rawlsunknown</td></tr><tr><td>Fried Green Tomatoes at the Whistle Stop Cafe by Fannie Flaggunknown</td></tr><tr><td>The Three Musketeers by Alexandre Dumasunknown</td></tr><tr><td>In Her Shoes by Jennifer Weinerunknown</td></tr><tr><td>The Andromeda Strain by Michael Crichtonunknown</td></tr><tr><td>Needful Things by Stephen Kingunknown</td></tr><tr><td>Are You There, Vodka? It's Me, Chelsea by Chelsea Handlerunknown</td></tr><tr><td>Prey by Michael Crichtonunknown</td></tr><tr><td>Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1) by Robert C. O'Brienunknown</td></tr><tr><td>The Little House Collection (Little House, #1-9) by Laura Ingalls Wilder, Garth Williamsunknown</td></tr><tr><td>The Girls' Guide to Hunting and Fishing by Melissa Bankunknown</td></tr><tr><td>Sh*t My Dad Says by Justin Halpernunknown</td></tr><tr><td>The Four Agreements: A Practical Guide to Personal Freed